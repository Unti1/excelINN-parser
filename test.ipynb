# %%
from tools import * 
from settings import *

# %%
p = Pars(True)
df = p.read_excel()

# %%
print(df.iloc[:,[4,11]])
print(df.iloc[:,4].count())
# Out:
#        Идентификационный номер налогоплательщика  \
# 0                                     5262128494
# 1                                     6154064277
# 2                                     7717129716
# 3                                     5024013262
# 4                                     2724093028
# ...                                          ...
# 28746                                 6829164080
# 28747                                 7203522460
# 28748                                 7840420324
# 28749                                 7813660849
# 28750                                 1101072966
#
#                                                 Сайт
# 0                                                NaN
# 1                                         softech.ru
# 2                                                NaN
# 3                                           logus.ru
# 4          portalkhv.ru, etop.portalkhv.ru, xab.info
# ...

# %%
df
# Out:
#        Регистрационный номер  Дата внесения записи  \
# 0                          1                 39468
# 1                          3                 39472
# 2                          4                 39472
# 3                          5                 39472
# 4                          6                 39472
# ...                      ...                   ...
# 28746                  30826                 44771
# 28747                  30827                 44772
# 28748                  30828                 44772
# 28749                  30829                 44772
# 28750                  30830                 44772
#
#                          Полное наименование организации  \
# 0      Общество с ограниченной ответственностью «ТЛМ ...
# 1      ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОГ...
# 2      Общество с ограниченной ответственностью «Лест...
# 3      Закрытое акционерное общество «Научно - произв...
# 4      Общество с ограниченной ответственностью «Порт...
# ...

# %%
print(df.iloc[0,4], df.iloc[0,11])
# Out:
# 5262128494 nan

# %%
df.iloc[0,11] = "link.ru"
print(df.iloc[0,4], df.iloc[0,11])
# Out:
# 5262128494 link.ru
